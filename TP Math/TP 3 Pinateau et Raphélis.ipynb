# %% [markdown]
# <p><span style="font-size: large; background-color: #ffffff; color: #000000;"><strong>Consignes :</strong></span></p>
# <ul>
# <li><span style="font-size: large; background-color: #ffffff; color: #000000;"><strong><strong>Renommer ce fichier en ordre alphab&eacute;tique <span style="color: #ff0000;">nom1-nom2-TP3</span></strong></strong></span></li>
# <li><span style="font-size: large; background-color: #ffffff; color: #000000;"><strong><strong><strong>TP &agrave; rendre sur campus&nbsp;<span><span style="color: #ff0000;">&agrave; la fin de la s&eacute;ance</span>.</span>&nbsp;</strong></strong></strong></span></li>
# <li><span style="font-size: large; background-color: #ffffff; color: #000000;"><strong>TP &agrave; faire en groupe de 2. Le groupe de travail sera le m&ecirc;me pour toute l'ann&eacute;e.</strong></span></li>
# <li><span style="font-size: large; background-color: #ffffff; color: #ff0000;"><span style="color: #000000;"><strong>&Agrave; completer :</strong></span></span></li>
# </ul>
# <p><span style="font-size: large; background-color: #ffffff; color: #ff0000;"><strong>Pinateau Pierre : <br /></strong></span></p>
# <p><span style="font-size: large; background-color: #ffffff; color: #ff0000;"><strong>Raphélis Vianney : </strong></span></p>
# <p>&nbsp;</p>
# <strong>TP 3 : Nombres complexes<br /></strong></span></span></p>
# <p>Avec Sage nous pouvons faire des calculs avec les nombres complexes.</p>
# <p>Le symbole <code class="docutils literal"><span class="pre">I</span></code> repr&eacute;sente la racine carr&eacute;e de<code class="docutils literal"><span class="pre"> -1. i</span></code> est synonyme de <code class="docutils literal"><span class="pre">I</span></code>. <strong></strong></p>
# <p><code class="docutils literal"><span class="pre">I</span></code> n&rsquo;appartient pas aux rationnels :</p>

# %%
I

# %%
i

# %%
I^2

# %%
i^2
# Out:
# -1

# %%
I in QQ
# Out:
# False

# %% [markdown]
# Le nombre décimal 1.2 est considéré comme un élément de QQ :

# %%
1.2 in QQ
# Out:
# True

# %% [markdown]
# <p>On peut calculer la partie r&eacute;elle (par la commande <strong><span style="font-family: courier new,courier;">real_part</span></strong>), la partie imaginaire (<strong><span style="font-family: courier new,courier;">imag_part</span></strong>), le module (<strong><span style="font-family: courier new,courier;">abs</span></strong>) et l'argument (<strong><span style="font-family: courier new,courier;">arg</span></strong>) d'un nombre complexe $z=ai+b$.</p>

# %%
i = 0
z=1+I
while(i<=10):
    mod = z^i
    print(mod,"\npartie réel :", real_part(mod),"\npartie imaginaire :", imag_part(mod),"\npour argument :",arg(mod),"\npour module :",abs(mod), "\n\n")
    i+=1
# Out:
# 1
# partie réel : 1
# partie imaginaire : 0
# pour argument : 0
# pour module : 1
#
#
# I + 1
# partie réel : 1
# partie imaginaire : 1
# pour argument : 1/4*pi
# pour module : sqrt(2)
#
#
# 2*I
# partie réel : 0
# partie imaginaire : 2
# pour argument : 1/2*pi
# pour module : 2
#
#
# 2*I - 2
# partie réel : -2
# partie imaginaire : 2
# pour argument : 3/4*pi
# pour module : 2*sqrt(2)
#
#
# -4
# partie réel : -4
# partie imaginaire : 0
# pour argument : pi
# pour module : 4
#
#
# -4*I - 4
# partie réel : -4
# partie imaginaire : -4
# pour argument : -3/4*pi
# pour module : 4*sqrt(2)
#
#
# -8*I
# partie réel : 0
# partie imaginaire : -8
# pour argument : -1/2*pi
# pour module : 8
#
#
# -8*I + 8
# partie réel : 8
# partie imaginaire : -8
# pour argument : -1/4*pi
# pour module : 8*sqrt(2)
#
#
# 16
# partie réel : 16
# partie imaginaire : 0
# pour argument : 0
# pour module : 16
#
#
# 16*I + 16
# partie réel : 16
# partie imaginaire : 16
# pour argument : 1/4*pi
# ...

# %%
z=1-I
print("\nreal part :", real_part(z), "\nimag part", imag_part(z), "\nModule :", abs(z), "\nArg :", arg(z))
# Out:
# real part : 1
# imag part -1
# Module : sqrt(2)
# Arg : -1/4*pi

# %% [markdown]
# <p><span style="text-decoration: underline;"><strong>EXERCICE 1</strong></span></p>
# <p>Calculer et afficher la partie re&eacute;lle, imaginaire, le module et l'argument de $z^0,z^1,z^2\ldots z^{10}$ avec $z=1+I$.<span style="text-decoration: underline;"><strong><br /></strong></span></p>

# %% [markdown]
# <p>Sage peut trouver les solutions d'une &eacute;quation.</p>
# <p>La fonction <strong><code class="docutils literal"><span class="pre">solve</span></code></strong> r&eacute;sout des &eacute;quations. Pour l&rsquo;utiliser, il convient de sp&eacute;cifier d&rsquo;abord les variables.</p>
# <p>Les arguments de <span style="font-family: courier new,courier;"><strong><code class="docutils literal"><span class="pre">solve</span></code></strong></span> sont alors une &eacute;quation suivie des variables &agrave; r&eacute;soudre.</p>

# %%
x = var('x')
solve(x^2-1,x)
# Out:
# [x == -1, x == 1]

# %% [markdown]
# <p><strong><span style="text-decoration: underline;">EXERCICE 2</span></strong></p>
# <p>R&eacute;soudre les &eacute;quations suivantes :<br /><br /></p>
# <ol>
# <li>$z^2+2z+5=0$</li>
# <li>$2z^2-(1+5\mathrm{i})z-2(1-\mathrm{i})=0$</li>
# <li>$z^3-(16-\mathrm{i})z^2+(89-16\mathrm{i})z+89\mathrm{i}=0$</li>
# </ol>

# %%
z = var('z')
print("1 :", solve(z^2 +2*z + 5,z))
print("\n2 :", solve(2*z^2-(1+5*I)*z-2*(1-I),z))
print("\n3 :", solve(z^3-(16-I)*z^2+(89-16*I)*z+89*I,z))
# Out:
# 1 : [
# z == (-2*I - 1),
# z == (2*I - 1)
# ]
#
# 2 : [
# z == -1/4*sqrt(-6*I - 8) + 5/4*I + 1/4,
# z == 1/4*sqrt(-6*I - 8) + 5/4*I + 1/4
# ]
#
# 3 : [
# z == -I,
# z == (-5*I + 8),
# z == (5*I + 8)
# ]

# %% [markdown]
# <p><strong><span style="text-decoration: underline;">EXERCICE 3</span> :</strong></p>
# <p>Soient&nbsp; $f_1$, $f_2$ et $f_3$ trois transformations du plan complexe d&eacute;finies par :</p>
# <ol style="list-style-type: lower-alpha;">
# <li>$f_1(z)=\frac{1}{2}z+\frac{1}{2}\mathrm{i}$&nbsp;</li>
# <li>$f_2(z)=\mathrm{i}z+1-\mathrm{i}$</li>
# <li>$f_3(z)=(2+\mathrm{i}) \overline{z}+1$</li>
# </ol>
# <p> et $A$, $B$, $C$ des points d'affixe respectivement</p>
# <ul>
# <li>$z_A = 0 $</li>
# <li>$z_B = \frac{1}{2}+\frac{1}{2}\mathrm{i}$</li>
# <li>$z_C = \frac{3}{2}+\frac{1}{3}\mathrm{i}$</li>
# </ul>
# <p>Repr&eacute;senter graphiquement les points $A$, $B$, $C$ et les respectives images par la fonction $f_1$</p>
# <p>&nbsp;</p>
# <p>SUGGESTIONS :</p>
# <ul>
# <li>Utiliser la commande <span style="font-family: courier new,courier;"><strong>point</strong></span></li>
# <li><span style="font-family: courier new,courier;"><span style="font-family: courier new,courier;"><span id="cell_outer_16"><span style="font-family: arial,helvetica,sans-serif;">Si vous voulez ajouter du texte sur le graphe, utiliser la commande<strong><span style="font-family: courier new,courier;"> text</span></strong></span></span></span></span></li>
# <li>On <span style="font-family: courier new,courier;"><span id="cell_outer_16"><span style="font-family: arial,helvetica,sans-serif;">peut dessiner sur le meme graphe plusieurs fonctions ou du texte avec le symbole <strong>+</strong> <br /></span></span></span></li>
# </ul>
# <p><span style="font-family: courier new,courier;"><span id="cell_outer_16"><span style="font-family: arial,helvetica,sans-serif;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Exemple : <strong><span style="font-family: courier new,courier;">point((2,3)) + text( "(2,3)", (2.1,3.1), xmin = 2, xmax = 3.5, ymin = 2, ymax = 3.5) </span></strong></span></span></span></p>

# %%
point((0,0)) + text( "A", (0.1,0)) + point((1/2,1/2)) + text( "B", (0.6,0.5)) + point((3/2,1/3)) + text( "C", (1.6,0.333)) + point((0,1/2)) + text( "A2", (0.1,0.5)) + point((1/4,3/4)) + text( "B2", (0.35,0.75)) + point((3/4,2/3)) + text( "C2", (0.85,0.666))
# Out:
# Graphics object consisting of 12 graphics primitives

# %% [markdown]
# <p><strong><span style="text-decoration: underline;">EXERCICE 4</span> :</strong></p>
# <ol style="list-style-type: lower-alpha;">
# <li>Utiliser la fonction ci-dessous (<strong>sim</strong>) pour repr&eacute;senter graphiquement le polygone definit par $A$, $B$, $C$ de l'exercice precedent et les respectives images par les trois fonctions $f_1$, $f_2$ et $f_3$.</li>
# <li>Experimenter l'utilisation de la fonction <strong>sim</strong> sur le polygone ABC et sur un autre exemple &agrave; choix.</li>
# </ol>

# %%
#Definition de la fonction similitude
#Entree : liste de points, paramètres de la similitude (z'=az+b) a et b, 
#         nombre de similitudes, si c=1, on calcule la similitude indirecte.
t = var('t')
def sim(P,a,b,numSim,c):
    g = Graphics();
    m=matrix(CC, numSim+1,len(P));
    for k in range(len(P)):
        m[0,k]=P[k];
    for k in range(len(P)-1) :
        g += line([(real(m[0,k]),imag(m[0,k])) , (real(m[0,k+1]),imag(m[0,k+1]))], color='red', aspect_ratio=1)
    if c == 1 :
        for k in range(len(P)):
            m[0,k]=conjugate(P[k]);  
    for n in range(numSim):
        for k in range(len(P)):
            m[n+1,k]=a*m[n,k]+b;
    for n in range(numSim):
        for k in range(len(P)-1) :
            g += line([(real(m[n+1,k]),imag(m[n+1,k])) , (real(m[n+1,k+1]),imag(m[n+1,k+1]))]) 
            g.set_aspect_ratio(1)
    return g

# %%
za = 0
zb = 1/2+1/2*I
zc = 3/2+1/3*I
P=[za,zb,zc,za]
sim(P,(1/2),1/2,1,0)
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# <p><strong><span><strong><span style="text-decoration: underline;">EXERCICE 5</span> :</strong> Repr&eacute;sentation des racines n-i&egrave;me de l'unit&eacute;</span></strong></p>
# <p>Dessiner les polygones r&eacute;guliers de 3, 4 et 5 c&ocirc;t&eacute;s.</p><br>
# <i>Suggestions :</i><br>
#
# <li>Vous pouvez utiliser la fonction <span style="font-family: courier new,courier;"><strong>sim</strong></span>.
# <li>Vous pouvez dessiner en plus le cercle trigonometrique avec la commande :<br>
# <span style="font-family: courier new,courier;"><strong>parametric_plot( (cos(t), sin(t)), (t, 0, 2*pi) ) <br /></strong>
# <li><span style="font-family: arial,helvetica,sans-serif;">On peut dessiner sur le meme graphe plusieurs fonctions avec le symbole + :</span><br>
# <span style="font-family: courier new,courier;"><strong><strong><strong>parametric_plot( (2*cos(t), sin(t)), (t, 0, 2*pi) )&nbsp;</strong> + parametric_plot( (cos(t), sin(t)), (t, 0, 2*pi) ) </strong></strong></span>

# %%
z=-1/2+I*sqrt(3)/2
P=[z**0,z**1,z**2,z**0]
parametric_plot( (cos(t), sin(t)), (t, 0, 2*pi) ) +sim(P,0,0,0,0)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
z=I
P=[z**0,z**1,z**2,z**3,z**0]
parametric_plot( (cos(t), sin(t)), (t, 0, 2*pi) ) +sim(P,0,0,0,0)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
z = cos(2*pi/5)+I*sin(2*pi/5)
P=[z**0,z**1,z**2,z**3,z**4,z**0]
parametric_plot( (cos(t), sin(t)), (t, 0, 2*pi) ) +sim(P,0,0,0,0)
# Out:
# Graphics object consisting of 6 graphics primitives
